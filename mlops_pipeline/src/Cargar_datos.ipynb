# %% [markdown]
# # Carga de datos
#
# Ingesta del dataset provisto (`Base_de_datos.xlsx`) y materialización
# como `Base_de_datos.csv` en la raíz del proyecto.
#
# Sin transformaciones: la limpieza se realiza en `comprension_eda.ipynb`.

# %%
import pandas as pd
from pathlib import Path

RUTA_PROYECTO = Path.cwd().parent.parent
ORIGEN = RUTA_PROYECTO / "Base_de_datos.xlsx"
DESTINO = RUTA_PROYECTO / "Base_de_datos.csv"

print("Origen:", ORIGEN)
print("Existe:", ORIGEN.exists())
# Out:
# Origen: c:\Proyectos\credit-risk-mlops\Base_de_datos.xlsx
# Existe: True

# %% [markdown]
# ## Lectura del archivo origen

# %%
df = pd.read_excel(ORIGEN)

print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
df.head()
# Out:
# Filas: 10763
# Columnas: 23
#    tipo_credito      fecha_prestamo  capital_prestado  plazo_meses  \
# 0             7 2024-12-21 11:31:35         3692160.0           10
# 1             4 2025-04-22 09:47:35          840000.0            6
# 2             9 2026-01-08 12:22:40         5974028.4           10
# 3             4 2025-08-04 12:04:10         1671240.0            6
# 4             9 2025-04-26 11:24:26         2781636.0           11
#
#    edad_cliente   tipo_laboral  salario_cliente  total_otros_prestamos  \
# 0            42  Independiente          8000000                2500000
# 1            60       Empleado          3000000                2000000
# 2            36  Independiente          4036000                 829000
# 3            48       Empleado          1524547                 498000
# 4            44       Empleado          5000000                4000000
#
#    cuota_pactada    puntaje  ...  saldo_mora  saldo_total  saldo_principal  \
# ...

# %%
df = pd.read_excel(ORIGEN)

print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
print(f"Duplicados: {df.duplicated().sum()}")
df.head()
# Out:
# Filas: 10763
# Columnas: 23
# Duplicados: 0
#    tipo_credito      fecha_prestamo  capital_prestado  plazo_meses  \
# 0             7 2024-12-21 11:31:35         3692160.0           10
# 1             4 2025-04-22 09:47:35          840000.0            6
# 2             9 2026-01-08 12:22:40         5974028.4           10
# 3             4 2025-08-04 12:04:10         1671240.0            6
# 4             9 2025-04-26 11:24:26         2781636.0           11
#
#    edad_cliente   tipo_laboral  salario_cliente  total_otros_prestamos  \
# 0            42  Independiente          8000000                2500000
# 1            60       Empleado          3000000                2000000
# 2            36  Independiente          4036000                 829000
# 3            48       Empleado          1524547                 498000
# 4            44       Empleado          5000000                4000000
#
#    cuota_pactada    puntaje  ...  saldo_mora  saldo_total  saldo_principal  \
# ...

# %% [markdown]
# ## Exportación a CSV

# %%
df.to_csv(DESTINO, index=False, encoding="utf-8")

print(f"Archivo generado: {DESTINO.name}")
print(f"Tamaño: {DESTINO.stat().st_size / 1024:.0f} KB")
# Out:
# Archivo generado: Base_de_datos.csv
# Tamaño: 1445 KB
